# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2

# %% [markdown]
# ### 배치 정규화 클래스 정의

# %%
class BatchNormalization(layers.BatchNormalization):
    def call(self, x, training=False):
        if not training:
            training = tf.constant(False)
        training = tf.logical_and(training, self.trainable)
        return super().call(x, training)

# %% [markdown]
# ### 배치 정규화와 LeakyReLU 활성화 함수를 사용하는 합성곱 함수

# %%
def convolutional(input_layer, filters, kernel_size, downsample=False, activate=True, bn=True):
    if downsample:
        input_layer = layers.ZeroPadding2D(((1,0), (1,0)))(input_layer)
        padding = 'valid'
        strides = 2
    else:
        strides = 1
        padding = 'same'

    kernel_init = tf.random_normal_initializer(stddev=0.01)
    conv = layers.Conv2D(filters=filters, kernel_size=kernel_size,
                         strides=strides, padding=padding,
                         use_bias=not bn,
                         kernel_initializer=kernel_init,
                         kernel_regularizer=l2(0.0005)
                        )(input_layer)
    if bn:
        conv = BatchNormalization()(conv)
    if activate:
        conv = layers.LeakyReLU(alpha=0.1)(conv)

    return conv

# %% [markdown]
# ### Rediual 블록

# %%
def residual_block(input_layer, filter_num1, filter_num2):
    short_cut = input_layer
    conv = convolutional(input_layer, filters=filter_num1, kernel_size=(1, 1))
    conv = convolutional(conv, filters=filter_num2, kernel_size=(3, 3))
    residual_output = short_cut + conv
    return residual_output

# %% [markdown]
# ### Darknet-53

# %%
def darknet53(input_data):
    input_data = convolutional(input_data, 32, (3, 3))
    input_data = convolutional(input_data, 64, (3, 3), downsample=True)

    for i in range(1):
        input_data = residual_block(input_data, 32, 64)

    input_data = convolutional(input_data, 128, (3, 3), downsample=True)

    for i in range(2):
        input_data = residual_block(input_data, 64, 128)

    input_data = convolutional(input_data, 256, (3, 3), downsample=True)

    for i in range(8):
        input_data = residual_block(input_data, 128, 256)

    route_1 = input_data
    input_data = convolutional(input_data, 512, (3, 3), downsample=True)

    for i in range(8):
        input_data = residual_block(input_data, 256, 512)

    route_2 = input_data
    input_data = convolutional(input_data, 1024, (3, 3), downsample=True)

    for i in range(4):
        input_data = residual_block(input_data, 512, 1024)

    return route_1, route_2, input_data

# %%
from tensorflow.keras.layers import Input
input = Input(shape=(416, 416, 3))
backbone = darknet53(input)

# %%
backbone
# Out:
# (<KerasTensor: shape=(None, 52, 52, 256) dtype=float32 (created by layer 'tf.__operators__.add_79')>,
#  <KerasTensor: shape=(None, 26, 26, 512) dtype=float32 (created by layer 'tf.__operators__.add_87')>,
#  <KerasTensor: shape=(None, 13, 13, 1024) dtype=float32 (created by layer 'tf.__operators__.add_91')>)

# %%
from tensorflow.keras.models import Model

# 모델 정의
model = Model(inputs=input, outputs=backbone[2])
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 416, 416, 3)]        0         []
#
#  conv2d_156 (Conv2D)         (None, 416, 416, 32)         864       ['input_4[0][0]']
#
#  batch_normalization_156 (B  (None, 416, 416, 32)         128       ['conv2d_156[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_156 (LeakyReLU  (None, 416, 416, 32)         0         ['batch_normalization_156[0][0
#  )                                                                  ]']
#
#  zero_padding2d_15 (ZeroPad  (None, 417, 417, 32)         0         ['leaky_re_lu_156[0][0]']
#  ding2D)
#
#  conv2d_157 (Conv2D)         (None, 208, 208, 64)         18432     ['zero_padding2d_15[0][0]']
#
#  batch_normalization_157 (B  (None, 208, 208, 64)         256       ['conv2d_157[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_157 (LeakyReLU  (None, 208, 208, 64)         0         ['batch_normalization_157[0][0
#  )                                                                  ]']
#
#  conv2d_158 (Conv2D)         (None, 208, 208, 32)         2048      ['leaky_re_lu_157[0][0]']
#
#  batch_normalization_158 (B  (None, 208, 208, 32)         128       ['conv2d_158[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_158 (LeakyReLU  (None, 208, 208, 32)         0         ['batch_normalization_158[0][0
#  )                                                                  ]']
#
#  conv2d_159 (Conv2D)         (None, 208, 208, 64)         18432     ['leaky_re_lu_158[0][0]']
#
#  batch_normalization_159 (B  (None, 208, 208, 64)         256       ['conv2d_159[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_159 (LeakyReLU  (None, 208, 208, 64)         0         ['batch_normalization_159[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_69 (T  (None, 208, 208, 64)         0         ['leaky_re_lu_157[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_159[0][0]']
#
#  zero_padding2d_16 (ZeroPad  (None, 209, 209, 64)         0         ['tf.__operators__.add_69[0][0
#  ding2D)                                                            ]']
#
#  conv2d_160 (Conv2D)         (None, 104, 104, 128)        73728     ['zero_padding2d_16[0][0]']
#
#  batch_normalization_160 (B  (None, 104, 104, 128)        512       ['conv2d_160[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_160 (LeakyReLU  (None, 104, 104, 128)        0         ['batch_normalization_160[0][0
#  )                                                                  ]']
#
#  conv2d_161 (Conv2D)         (None, 104, 104, 64)         8192      ['leaky_re_lu_160[0][0]']
#
#  batch_normalization_161 (B  (None, 104, 104, 64)         256       ['conv2d_161[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_161 (LeakyReLU  (None, 104, 104, 64)         0         ['batch_normalization_161[0][0
#  )                                                                  ]']
#
#  conv2d_162 (Conv2D)         (None, 104, 104, 128)        73728     ['leaky_re_lu_161[0][0]']
#
#  batch_normalization_162 (B  (None, 104, 104, 128)        512       ['conv2d_162[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_162 (LeakyReLU  (None, 104, 104, 128)        0         ['batch_normalization_162[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_70 (T  (None, 104, 104, 128)        0         ['leaky_re_lu_160[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_162[0][0]']
#
#  conv2d_163 (Conv2D)         (None, 104, 104, 64)         8192      ['tf.__operators__.add_70[0][0
#                                                                     ]']
#
#  batch_normalization_163 (B  (None, 104, 104, 64)         256       ['conv2d_163[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_163 (LeakyReLU  (None, 104, 104, 64)         0         ['batch_normalization_163[0][0
#  )                                                                  ]']
#
#  conv2d_164 (Conv2D)         (None, 104, 104, 128)        73728     ['leaky_re_lu_163[0][0]']
#
#  batch_normalization_164 (B  (None, 104, 104, 128)        512       ['conv2d_164[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_164 (LeakyReLU  (None, 104, 104, 128)        0         ['batch_normalization_164[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_71 (T  (None, 104, 104, 128)        0         ['tf.__operators__.add_70[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_164[0][0]']
#
#  zero_padding2d_17 (ZeroPad  (None, 105, 105, 128)        0         ['tf.__operators__.add_71[0][0
#  ding2D)                                                            ]']
#
#  conv2d_165 (Conv2D)         (None, 52, 52, 256)          294912    ['zero_padding2d_17[0][0]']
#
#  batch_normalization_165 (B  (None, 52, 52, 256)          1024      ['conv2d_165[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_165 (LeakyReLU  (None, 52, 52, 256)          0         ['batch_normalization_165[0][0
#  )                                                                  ]']
#
#  conv2d_166 (Conv2D)         (None, 52, 52, 128)          32768     ['leaky_re_lu_165[0][0]']
#
#  batch_normalization_166 (B  (None, 52, 52, 128)          512       ['conv2d_166[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_166 (LeakyReLU  (None, 52, 52, 128)          0         ['batch_normalization_166[0][0
#  )                                                                  ]']
#
#  conv2d_167 (Conv2D)         (None, 52, 52, 256)          294912    ['leaky_re_lu_166[0][0]']
#
#  batch_normalization_167 (B  (None, 52, 52, 256)          1024      ['conv2d_167[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_167 (LeakyReLU  (None, 52, 52, 256)          0         ['batch_normalization_167[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_72 (T  (None, 52, 52, 256)          0         ['leaky_re_lu_165[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_167[0][0]']
#
#  conv2d_168 (Conv2D)         (None, 52, 52, 128)          32768     ['tf.__operators__.add_72[0][0
#                                                                     ]']
#
#  batch_normalization_168 (B  (None, 52, 52, 128)          512       ['conv2d_168[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_168 (LeakyReLU  (None, 52, 52, 128)          0         ['batch_normalization_168[0][0
#  )                                                                  ]']
#
#  conv2d_169 (Conv2D)         (None, 52, 52, 256)          294912    ['leaky_re_lu_168[0][0]']
#
#  batch_normalization_169 (B  (None, 52, 52, 256)          1024      ['conv2d_169[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_169 (LeakyReLU  (None, 52, 52, 256)          0         ['batch_normalization_169[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_73 (T  (None, 52, 52, 256)          0         ['tf.__operators__.add_72[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_169[0][0]']
#
#  conv2d_170 (Conv2D)         (None, 52, 52, 128)          32768     ['tf.__operators__.add_73[0][0
#                                                                     ]']
#
#  batch_normalization_170 (B  (None, 52, 52, 128)          512       ['conv2d_170[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_170 (LeakyReLU  (None, 52, 52, 128)          0         ['batch_normalization_170[0][0
#  )                                                                  ]']
#
#  conv2d_171 (Conv2D)         (None, 52, 52, 256)          294912    ['leaky_re_lu_170[0][0]']
#
#  batch_normalization_171 (B  (None, 52, 52, 256)          1024      ['conv2d_171[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_171 (LeakyReLU  (None, 52, 52, 256)          0         ['batch_normalization_171[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_74 (T  (None, 52, 52, 256)          0         ['tf.__operators__.add_73[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_171[0][0]']
#
#  conv2d_172 (Conv2D)         (None, 52, 52, 128)          32768     ['tf.__operators__.add_74[0][0
#                                                                     ]']
#
#  batch_normalization_172 (B  (None, 52, 52, 128)          512       ['conv2d_172[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_172 (LeakyReLU  (None, 52, 52, 128)          0         ['batch_normalization_172[0][0
#  )                                                                  ]']
#
#  conv2d_173 (Conv2D)         (None, 52, 52, 256)          294912    ['leaky_re_lu_172[0][0]']
#
#  batch_normalization_173 (B  (None, 52, 52, 256)          1024      ['conv2d_173[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_173 (LeakyReLU  (None, 52, 52, 256)          0         ['batch_normalization_173[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_75 (T  (None, 52, 52, 256)          0         ['tf.__operators__.add_74[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_173[0][0]']
#
#  conv2d_174 (Conv2D)         (None, 52, 52, 128)          32768     ['tf.__operators__.add_75[0][0
#                                                                     ]']
#
#  batch_normalization_174 (B  (None, 52, 52, 128)          512       ['conv2d_174[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_174 (LeakyReLU  (None, 52, 52, 128)          0         ['batch_normalization_174[0][0
#  )                                                                  ]']
#
#  conv2d_175 (Conv2D)         (None, 52, 52, 256)          294912    ['leaky_re_lu_174[0][0]']
#
#  batch_normalization_175 (B  (None, 52, 52, 256)          1024      ['conv2d_175[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_175 (LeakyReLU  (None, 52, 52, 256)          0         ['batch_normalization_175[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_76 (T  (None, 52, 52, 256)          0         ['tf.__operators__.add_75[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_175[0][0]']
#
#  conv2d_176 (Conv2D)         (None, 52, 52, 128)          32768     ['tf.__operators__.add_76[0][0
#                                                                     ]']
#
#  batch_normalization_176 (B  (None, 52, 52, 128)          512       ['conv2d_176[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_176 (LeakyReLU  (None, 52, 52, 128)          0         ['batch_normalization_176[0][0
#  )                                                                  ]']
#
#  conv2d_177 (Conv2D)         (None, 52, 52, 256)          294912    ['leaky_re_lu_176[0][0]']
#
#  batch_normalization_177 (B  (None, 52, 52, 256)          1024      ['conv2d_177[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_177 (LeakyReLU  (None, 52, 52, 256)          0         ['batch_normalization_177[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_77 (T  (None, 52, 52, 256)          0         ['tf.__operators__.add_76[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_177[0][0]']
#
#  conv2d_178 (Conv2D)         (None, 52, 52, 128)          32768     ['tf.__operators__.add_77[0][0
#                                                                     ]']
#
#  batch_normalization_178 (B  (None, 52, 52, 128)          512       ['conv2d_178[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_178 (LeakyReLU  (None, 52, 52, 128)          0         ['batch_normalization_178[0][0
#  )                                                                  ]']
#
#  conv2d_179 (Conv2D)         (None, 52, 52, 256)          294912    ['leaky_re_lu_178[0][0]']
#
#  batch_normalization_179 (B  (None, 52, 52, 256)          1024      ['conv2d_179[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_179 (LeakyReLU  (None, 52, 52, 256)          0         ['batch_normalization_179[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_78 (T  (None, 52, 52, 256)          0         ['tf.__operators__.add_77[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_179[0][0]']
#
#  conv2d_180 (Conv2D)         (None, 52, 52, 128)          32768     ['tf.__operators__.add_78[0][0
#                                                                     ]']
#
#  batch_normalization_180 (B  (None, 52, 52, 128)          512       ['conv2d_180[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_180 (LeakyReLU  (None, 52, 52, 128)          0         ['batch_normalization_180[0][0
#  )                                                                  ]']
#
#  conv2d_181 (Conv2D)         (None, 52, 52, 256)          294912    ['leaky_re_lu_180[0][0]']
#
#  batch_normalization_181 (B  (None, 52, 52, 256)          1024      ['conv2d_181[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_181 (LeakyReLU  (None, 52, 52, 256)          0         ['batch_normalization_181[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_79 (T  (None, 52, 52, 256)          0         ['tf.__operators__.add_78[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_181[0][0]']
#
#  zero_padding2d_18 (ZeroPad  (None, 53, 53, 256)          0         ['tf.__operators__.add_79[0][0
#  ding2D)                                                            ]']
#
#  conv2d_182 (Conv2D)         (None, 26, 26, 512)          1179648   ['zero_padding2d_18[0][0]']
#
#  batch_normalization_182 (B  (None, 26, 26, 512)          2048      ['conv2d_182[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_182 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_182[0][0
#  )                                                                  ]']
#
#  conv2d_183 (Conv2D)         (None, 26, 26, 256)          131072    ['leaky_re_lu_182[0][0]']
#
#  batch_normalization_183 (B  (None, 26, 26, 256)          1024      ['conv2d_183[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_183 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_183[0][0
#  )                                                                  ]']
#
#  conv2d_184 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_183[0][0]']
#
#  batch_normalization_184 (B  (None, 26, 26, 512)          2048      ['conv2d_184[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_184 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_184[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_80 (T  (None, 26, 26, 512)          0         ['leaky_re_lu_182[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_184[0][0]']
#
#  conv2d_185 (Conv2D)         (None, 26, 26, 256)          131072    ['tf.__operators__.add_80[0][0
#                                                                     ]']
#
#  batch_normalization_185 (B  (None, 26, 26, 256)          1024      ['conv2d_185[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_185 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_185[0][0
#  )                                                                  ]']
#
#  conv2d_186 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_185[0][0]']
#
#  batch_normalization_186 (B  (None, 26, 26, 512)          2048      ['conv2d_186[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_186 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_186[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_81 (T  (None, 26, 26, 512)          0         ['tf.__operators__.add_80[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_186[0][0]']
#
#  conv2d_187 (Conv2D)         (None, 26, 26, 256)          131072    ['tf.__operators__.add_81[0][0
#                                                                     ]']
#
#  batch_normalization_187 (B  (None, 26, 26, 256)          1024      ['conv2d_187[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_187 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_187[0][0
#  )                                                                  ]']
#
#  conv2d_188 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_187[0][0]']
#
#  batch_normalization_188 (B  (None, 26, 26, 512)          2048      ['conv2d_188[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_188 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_188[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_82 (T  (None, 26, 26, 512)          0         ['tf.__operators__.add_81[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_188[0][0]']
#
#  conv2d_189 (Conv2D)         (None, 26, 26, 256)          131072    ['tf.__operators__.add_82[0][0
#                                                                     ]']
#
#  batch_normalization_189 (B  (None, 26, 26, 256)          1024      ['conv2d_189[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_189 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_189[0][0
#  )                                                                  ]']
#
#  conv2d_190 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_189[0][0]']
#
#  batch_normalization_190 (B  (None, 26, 26, 512)          2048      ['conv2d_190[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_190 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_190[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_83 (T  (None, 26, 26, 512)          0         ['tf.__operators__.add_82[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_190[0][0]']
#
#  conv2d_191 (Conv2D)         (None, 26, 26, 256)          131072    ['tf.__operators__.add_83[0][0
#                                                                     ]']
#
#  batch_normalization_191 (B  (None, 26, 26, 256)          1024      ['conv2d_191[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_191 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_191[0][0
#  )                                                                  ]']
#
#  conv2d_192 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_191[0][0]']
#
#  batch_normalization_192 (B  (None, 26, 26, 512)          2048      ['conv2d_192[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_192 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_192[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_84 (T  (None, 26, 26, 512)          0         ['tf.__operators__.add_83[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_192[0][0]']
#
#  conv2d_193 (Conv2D)         (None, 26, 26, 256)          131072    ['tf.__operators__.add_84[0][0
#                                                                     ]']
#
#  batch_normalization_193 (B  (None, 26, 26, 256)          1024      ['conv2d_193[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_193 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_193[0][0
#  )                                                                  ]']
#
#  conv2d_194 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_193[0][0]']
#
#  batch_normalization_194 (B  (None, 26, 26, 512)          2048      ['conv2d_194[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_194 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_194[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_85 (T  (None, 26, 26, 512)          0         ['tf.__operators__.add_84[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_194[0][0]']
#
#  conv2d_195 (Conv2D)         (None, 26, 26, 256)          131072    ['tf.__operators__.add_85[0][0
#                                                                     ]']
#
#  batch_normalization_195 (B  (None, 26, 26, 256)          1024      ['conv2d_195[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_195 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_195[0][0
#  )                                                                  ]']
#
#  conv2d_196 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_195[0][0]']
#
#  batch_normalization_196 (B  (None, 26, 26, 512)          2048      ['conv2d_196[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_196 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_196[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_86 (T  (None, 26, 26, 512)          0         ['tf.__operators__.add_85[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_196[0][0]']
#
#  conv2d_197 (Conv2D)         (None, 26, 26, 256)          131072    ['tf.__operators__.add_86[0][0
#                                                                     ]']
#
#  batch_normalization_197 (B  (None, 26, 26, 256)          1024      ['conv2d_197[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_197 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_197[0][0
#  )                                                                  ]']
#
#  conv2d_198 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_197[0][0]']
#
#  batch_normalization_198 (B  (None, 26, 26, 512)          2048      ['conv2d_198[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_198 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_198[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_87 (T  (None, 26, 26, 512)          0         ['tf.__operators__.add_86[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_198[0][0]']
#
#  zero_padding2d_19 (ZeroPad  (None, 27, 27, 512)          0         ['tf.__operators__.add_87[0][0
#  ding2D)                                                            ]']
#
#  conv2d_199 (Conv2D)         (None, 13, 13, 1024)         4718592   ['zero_padding2d_19[0][0]']
#
#  batch_normalization_199 (B  (None, 13, 13, 1024)         4096      ['conv2d_199[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_199 (LeakyReLU  (None, 13, 13, 1024)         0         ['batch_normalization_199[0][0
#  )                                                                  ]']
#
#  conv2d_200 (Conv2D)         (None, 13, 13, 512)          524288    ['leaky_re_lu_199[0][0]']
#
#  batch_normalization_200 (B  (None, 13, 13, 512)          2048      ['conv2d_200[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_200 (LeakyReLU  (None, 13, 13, 512)          0         ['batch_normalization_200[0][0
#  )                                                                  ]']
#
#  conv2d_201 (Conv2D)         (None, 13, 13, 1024)         4718592   ['leaky_re_lu_200[0][0]']
#
#  batch_normalization_201 (B  (None, 13, 13, 1024)         4096      ['conv2d_201[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_201 (LeakyReLU  (None, 13, 13, 1024)         0         ['batch_normalization_201[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_88 (T  (None, 13, 13, 1024)         0         ['leaky_re_lu_199[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_201[0][0]']
#
#  conv2d_202 (Conv2D)         (None, 13, 13, 512)          524288    ['tf.__operators__.add_88[0][0
#                                                                     ]']
#
#  batch_normalization_202 (B  (None, 13, 13, 512)          2048      ['conv2d_202[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_202 (LeakyReLU  (None, 13, 13, 512)          0         ['batch_normalization_202[0][0
#  )                                                                  ]']
#
#  conv2d_203 (Conv2D)         (None, 13, 13, 1024)         4718592   ['leaky_re_lu_202[0][0]']
#
#  batch_normalization_203 (B  (None, 13, 13, 1024)         4096      ['conv2d_203[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_203 (LeakyReLU  (None, 13, 13, 1024)         0         ['batch_normalization_203[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_89 (T  (None, 13, 13, 1024)         0         ['tf.__operators__.add_88[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_203[0][0]']
#
#  conv2d_204 (Conv2D)         (None, 13, 13, 512)          524288    ['tf.__operators__.add_89[0][0
#                                                                     ]']
#
#  batch_normalization_204 (B  (None, 13, 13, 512)          2048      ['conv2d_204[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_204 (LeakyReLU  (None, 13, 13, 512)          0         ['batch_normalization_204[0][0
#  )                                                                  ]']
#
#  conv2d_205 (Conv2D)         (None, 13, 13, 1024)         4718592   ['leaky_re_lu_204[0][0]']
#
#  batch_normalization_205 (B  (None, 13, 13, 1024)         4096      ['conv2d_205[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_205 (LeakyReLU  (None, 13, 13, 1024)         0         ['batch_normalization_205[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_90 (T  (None, 13, 13, 1024)         0         ['tf.__operators__.add_89[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_205[0][0]']
#
#  conv2d_206 (Conv2D)         (None, 13, 13, 512)          524288    ['tf.__operators__.add_90[0][0
#                                                                     ]']
#
#  batch_normalization_206 (B  (None, 13, 13, 512)          2048      ['conv2d_206[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_206 (LeakyReLU  (None, 13, 13, 512)          0         ['batch_normalization_206[0][0
#  )                                                                  ]']
#
#  conv2d_207 (Conv2D)         (None, 13, 13, 1024)         4718592   ['leaky_re_lu_206[0][0]']
#
#  batch_normalization_207 (B  (None, 13, 13, 1024)         4096      ['conv2d_207[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_207 (LeakyReLU  (None, 13, 13, 1024)         0         ['batch_normalization_207[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_91 (T  (None, 13, 13, 1024)         0         ['tf.__operators__.add_90[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_207[0][0]']
#
# ==================================================================================================
# Total params: 40620640 (154.96 MB)
# Trainable params: 40584928 (154.82 MB)
# Non-trainable params: 35712 (139.50 KB)
# __________________________________________________________________________________________________
