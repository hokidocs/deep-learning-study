# %% [markdown]
# ![image.png](attachment:7a055a82-717e-4fb9-a522-c6413728acf7.png)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2

# %% [markdown]
# ### 배치 정규화 클래스 정의

# %%
class BatchNormalization(layers.BatchNormalization):
    def call(self, x, training=False):
        if not training:
            training = tf.constant(False)
        training = tf.logical_and(training, self.trainable)
        return super().call(x, training)

# %% [markdown]
# ### 배치 정규화와 LeakyReLU 활성화 함수를 사용하는 합성곱 함수
# ![image.png](attachment:432d5941-fc0e-4894-a620-a99da6f3cd91.png)

# %%
def convolutional(input_layer, filters, kernel_size, downsample=False, activate=True, bn=True):
    if downsample:
        input_layer = layers.ZeroPadding2D(((1,0), (1,0)))(input_layer)
        padding = 'valid'
        strides = 2
    else:
        strides = 1
        padding = 'same'

    kernel_init = tf.random_normal_initializer(stddev=0.01)
    conv = layers.Conv2D(filters=filters, kernel_size=kernel_size,
                         strides=strides, padding=padding,
                         use_bias=not bn,
                         kernel_initializer=kernel_init,
                         kernel_regularizer=l2(0.0005)
                        )(input_layer)
    if bn:
        conv = BatchNormalization()(conv)
    if activate:
        conv = layers.LeakyReLU(alpha=0.1)(conv)

    return conv

# %% [markdown]
# ### Rediual 블록
# ![image.png](attachment:f4444e31-2fcf-4a59-bfd9-abee13ed7975.png)

# %%
def residual_block(input_layer, filter_num1, filter_num2):
    short_cut = input_layer
    conv = convolutional(input_layer, filters=filter_num1, kernel_size=(1, 1))
    conv = convolutional(conv, filters=filter_num2, kernel_size=(3, 3))
    residual_output = short_cut + conv
    return residual_output

# %% [markdown]
# ### Darknet-53

# %%
def darknet53(input_data):
    input_data = convolutional(input_data, 32, (3, 3))
    input_data = convolutional(input_data, 64, (3, 3), downsample=True)

    for i in range(1):
        input_data = residual_block(input_data, 32, 64)

    input_data = convolutional(input_data, 128, (3, 3), downsample=True)

    for i in range(2):
        input_data = residual_block(input_data, 64, 128)

    input_data = convolutional(input_data, 256, (3, 3), downsample=True)

    for i in range(8):
        input_data = residual_block(input_data, 128, 256)

    route_1 = input_data
    input_data = convolutional(input_data, 512, (3, 3), downsample=True)

    for i in range(8):
        input_data = residual_block(input_data, 256, 512)

    route_2 = input_data
    input_data = convolutional(input_data, 1024, (3, 3), downsample=True)

    for i in range(4):
        input_data = residual_block(input_data, 512, 1024)

    return route_1, route_2, input_data

# %% [markdown]
# ### Up Sampling

# %%
def upsample(input_layer):
    width, height = input_layer.shape[1], input_layer.shape[2]
    output_layer = tf.image.resize(input_layer, (width*2, height*2), method='nearest')

    return output_layer

# %% [markdown]
# ### YOLOv3

# %%
def YOLOv3(input_layer, num_class):
    route_1, route_2, conv = darknet53(input_layer)

    conv = convolutional(conv, 512, (1, 1))
    conv = convolutional(conv, 1024, (3, 3))
    conv = convolutional(conv, 512, (1, 1))
    conv = convolutional(conv, 1024, (3, 3))
    conv = convolutional(conv, 512, (1, 1))
    conv_lobj_branch = convolutional(conv, 1024, (3, 3))

    conv_lbbox = convolutional(conv_lobj_branch, 3 * (num_class + 5), (1, 1), activate=False, bn=False)

    conv = convolutional(conv, 256, (1, 1))

    conv = upsample(conv)

    conv = tf.concat([conv, route_2], axis=-1)
    conv = convolutional(conv, 256, (1, 1))
    conv = convolutional(conv, 512, (3, 3))
    conv = convolutional(conv, 256, (1, 1))
    conv = convolutional(conv, 512, (3, 3))
    conv = convolutional(conv, 256, (1, 1))
    conv_mobj_branch = convolutional(conv, 512, (3, 3))

    conv_mbbox = convolutional(conv_mobj_branch, 3 * (num_class + 5), (1, 1), activate=False, bn=False)

    conv = convolutional(conv, 128, (1, 1))
    conv = upsample(conv)

    conv = tf.concat([conv, route_1], axis=-1)
    conv = convolutional(conv, 128, (1, 1))
    conv = convolutional(conv, 256, (3, 3))
    conv = convolutional(conv, 128, (1, 1))
    conv = convolutional(conv, 256, (3, 3))
    conv = convolutional(conv, 128, (1, 1))
    conv_sobj_branch = convolutional(conv, 256, (3, 3))

    conv_sbbox = convolutional(conv_sobj_branch, 3 * (num_class + 5), (1, 1), activate=False, bn=False)

    return [conv_sbbox, conv_mbbox, conv_lbbox]

# %% [markdown]
# ### 정보 확인

# %%
import numpy as np

YOLO_STRIDES = [8, 16, 32]
YOLO_ANCHORS = [[[10, 13], [16, 30], [33, 23]],
                [[30, 61], [62, 45], [59, 119]],
                [[116, 90], [156, 198], [373, 326]]]
STRIDES = np.array(YOLO_STRIDES)
ANCHORS = (np.array(YOLO_ANCHORS).T/STRIDES).T

# %% [markdown]
# ### 디코더

# %%
def decode(conv_output, num_class, i=0):
    conv_shape = tf.shape(conv_output)
    batch_size = conv_shape[0]
    output_size = conv_shape[1]

    conv_output = tf.reshape(conv_output, (batch_size, output_size, output_size, 3, num_class+5))

    conv_raw_dxdy = conv_output[:, :, :, :, 0:2]
    conv_raw_dwdh = conv_output[:, :, :, :, 2:4]
    conv_raw_conf = conv_output[:, :, :, :, 4:5]
    conv_raw_prob = conv_output[:, :, :, :, 5: ]

    y = tf.range(output_size, dtype=tf.int32)
    y = tf.expand_dims(y, -1)
    y = tf.tile(y, [1, output_size])
    x = tf.range(output_size, dtype=tf.int32)
    x = tf.expand_dims(x, 0)
    x = tf.tile(x, [output_size, 1])

    xy_grid = tf.concat([x[:, :, tf.newaxis], y[:, :, tf.newaxis]], axis=-1)
    xy_grid = tf.tile(xy_grid[tf.newaxis, :, :, tf.newaxis, :], [batch_size, 1, 1, 3, 1])
    xy_grid = tf.cast(xy_grid, tf.float32)

    pred_xy = (tf.sigmoid(conv_raw_dxdy) + xy_grid) * STRIDES[i]

    pred_wh = (tf.exp(conv_raw_dwdh) * ANCHORS[i]) * STRIDES[i]

    pred_xywh = tf.concat([pred_xy, pred_wh], axis=-1)
    pred_conf = tf.sigmoid(conv_raw_conf)
    pred_prob = tf.sigmoid(conv_raw_prob)

    return tf.concat([pred_xywh, pred_conf, pred_prob], axis=-1)

# %%
def Create_YOLOv3(num_class, input_shape=(416, 416, 3), train_mode=False):
    input_layer = layers.Input(input_shape)
    conv_tensors = YOLOv3(input_layer, num_class)
    output_tensors = []
    for i, conv_tensor in enumerate(conv_tensors):
        pred_tensor = decode(conv_tensor, num_class, i)
        if train_mode : output_tensors.append(conv_tensor)
        output_tensors.append(pred_tensor)
    model = tf.keras.Model(input_layer, output_tensors)

    return model

# %%
NUM_CLASS = 10
yolo = Create_YOLOv3(num_class=NUM_CLASS, train_mode=True)
yolo.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 416, 416, 3)]        0         []
#
#  conv2d_593 (Conv2D)         (None, 416, 416, 32)         864       ['input_9[0][0]']
#
#  batch_normalization_570 (B  (None, 416, 416, 32)         128       ['conv2d_593[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_570 (LeakyReLU  (None, 416, 416, 32)         0         ['batch_normalization_570[0][0
#  )                                                                  ]']
#
#  zero_padding2d_40 (ZeroPad  (None, 417, 417, 32)         0         ['leaky_re_lu_570[0][0]']
#  ding2D)
#
#  conv2d_594 (Conv2D)         (None, 208, 208, 64)         18432     ['zero_padding2d_40[0][0]']
#
#  batch_normalization_571 (B  (None, 208, 208, 64)         256       ['conv2d_594[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_571 (LeakyReLU  (None, 208, 208, 64)         0         ['batch_normalization_571[0][0
#  )                                                                  ]']
#
#  conv2d_595 (Conv2D)         (None, 208, 208, 32)         2048      ['leaky_re_lu_571[0][0]']
#
#  batch_normalization_572 (B  (None, 208, 208, 32)         128       ['conv2d_595[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_572 (LeakyReLU  (None, 208, 208, 32)         0         ['batch_normalization_572[0][0
#  )                                                                  ]']
#
#  conv2d_596 (Conv2D)         (None, 208, 208, 64)         18432     ['leaky_re_lu_572[0][0]']
#
#  batch_normalization_573 (B  (None, 208, 208, 64)         256       ['conv2d_596[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_573 (LeakyReLU  (None, 208, 208, 64)         0         ['batch_normalization_573[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_188 (  (None, 208, 208, 64)         0         ['leaky_re_lu_571[0][0]',
#  TFOpLambda)                                                         'leaky_re_lu_573[0][0]']
#
#  zero_padding2d_41 (ZeroPad  (None, 209, 209, 64)         0         ['tf.__operators__.add_188[0][
#  ding2D)                                                            0]']
#
#  conv2d_597 (Conv2D)         (None, 104, 104, 128)        73728     ['zero_padding2d_41[0][0]']
#
#  batch_normalization_574 (B  (None, 104, 104, 128)        512       ['conv2d_597[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_574 (LeakyReLU  (None, 104, 104, 128)        0         ['batch_normalization_574[0][0
#  )                                                                  ]']
#
#  conv2d_598 (Conv2D)         (None, 104, 104, 64)         8192      ['leaky_re_lu_574[0][0]']
#
#  batch_normalization_575 (B  (None, 104, 104, 64)         256       ['conv2d_598[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_575 (LeakyReLU  (None, 104, 104, 64)         0         ['batch_normalization_575[0][0
#  )                                                                  ]']
#
#  conv2d_599 (Conv2D)         (None, 104, 104, 128)        73728     ['leaky_re_lu_575[0][0]']
#
#  batch_normalization_576 (B  (None, 104, 104, 128)        512       ['conv2d_599[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_576 (LeakyReLU  (None, 104, 104, 128)        0         ['batch_normalization_576[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_189 (  (None, 104, 104, 128)        0         ['leaky_re_lu_574[0][0]',
#  TFOpLambda)                                                         'leaky_re_lu_576[0][0]']
#
#  conv2d_600 (Conv2D)         (None, 104, 104, 64)         8192      ['tf.__operators__.add_189[0][
#                                                                     0]']
#
#  batch_normalization_577 (B  (None, 104, 104, 64)         256       ['conv2d_600[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_577 (LeakyReLU  (None, 104, 104, 64)         0         ['batch_normalization_577[0][0
#  )                                                                  ]']
#
#  conv2d_601 (Conv2D)         (None, 104, 104, 128)        73728     ['leaky_re_lu_577[0][0]']
#
#  batch_normalization_578 (B  (None, 104, 104, 128)        512       ['conv2d_601[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_578 (LeakyReLU  (None, 104, 104, 128)        0         ['batch_normalization_578[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_190 (  (None, 104, 104, 128)        0         ['tf.__operators__.add_189[0][
#  TFOpLambda)                                                        0]',
#                                                                      'leaky_re_lu_578[0][0]']
#
#  zero_padding2d_42 (ZeroPad  (None, 105, 105, 128)        0         ['tf.__operators__.add_190[0][
#  ding2D)                                                            0]']
#
#  conv2d_602 (Conv2D)         (None, 52, 52, 256)          294912    ['zero_padding2d_42[0][0]']
#
#  batch_normalization_579 (B  (None, 52, 52, 256)          1024      ['conv2d_602[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_579 (LeakyReLU  (None, 52, 52, 256)          0         ['batch_normalization_579[0][0
#  )                                                                  ]']
#
#  conv2d_603 (Conv2D)         (None, 52, 52, 128)          32768     ['leaky_re_lu_579[0][0]']
#
#  batch_normalization_580 (B  (None, 52, 52, 128)          512       ['conv2d_603[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_580 (LeakyReLU  (None, 52, 52, 128)          0         ['batch_normalization_580[0][0
#  )                                                                  ]']
#
#  conv2d_604 (Conv2D)         (None, 52, 52, 256)          294912    ['leaky_re_lu_580[0][0]']
#
#  batch_normalization_581 (B  (None, 52, 52, 256)          1024      ['conv2d_604[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_581 (LeakyReLU  (None, 52, 52, 256)          0         ['batch_normalization_581[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_191 (  (None, 52, 52, 256)          0         ['leaky_re_lu_579[0][0]',
#  TFOpLambda)                                                         'leaky_re_lu_581[0][0]']
#
#  conv2d_605 (Conv2D)         (None, 52, 52, 128)          32768     ['tf.__operators__.add_191[0][
#                                                                     0]']
#
#  batch_normalization_582 (B  (None, 52, 52, 128)          512       ['conv2d_605[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_582 (LeakyReLU  (None, 52, 52, 128)          0         ['batch_normalization_582[0][0
#  )                                                                  ]']
#
#  conv2d_606 (Conv2D)         (None, 52, 52, 256)          294912    ['leaky_re_lu_582[0][0]']
#
#  batch_normalization_583 (B  (None, 52, 52, 256)          1024      ['conv2d_606[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_583 (LeakyReLU  (None, 52, 52, 256)          0         ['batch_normalization_583[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_192 (  (None, 52, 52, 256)          0         ['tf.__operators__.add_191[0][
#  TFOpLambda)                                                        0]',
#                                                                      'leaky_re_lu_583[0][0]']
#
#  conv2d_607 (Conv2D)         (None, 52, 52, 128)          32768     ['tf.__operators__.add_192[0][
#                                                                     0]']
#
#  batch_normalization_584 (B  (None, 52, 52, 128)          512       ['conv2d_607[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_584 (LeakyReLU  (None, 52, 52, 128)          0         ['batch_normalization_584[0][0
#  )                                                                  ]']
#
#  conv2d_608 (Conv2D)         (None, 52, 52, 256)          294912    ['leaky_re_lu_584[0][0]']
#
#  batch_normalization_585 (B  (None, 52, 52, 256)          1024      ['conv2d_608[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_585 (LeakyReLU  (None, 52, 52, 256)          0         ['batch_normalization_585[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_193 (  (None, 52, 52, 256)          0         ['tf.__operators__.add_192[0][
#  TFOpLambda)                                                        0]',
#                                                                      'leaky_re_lu_585[0][0]']
#
#  conv2d_609 (Conv2D)         (None, 52, 52, 128)          32768     ['tf.__operators__.add_193[0][
#                                                                     0]']
#
#  batch_normalization_586 (B  (None, 52, 52, 128)          512       ['conv2d_609[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_586 (LeakyReLU  (None, 52, 52, 128)          0         ['batch_normalization_586[0][0
#  )                                                                  ]']
#
#  conv2d_610 (Conv2D)         (None, 52, 52, 256)          294912    ['leaky_re_lu_586[0][0]']
#
#  batch_normalization_587 (B  (None, 52, 52, 256)          1024      ['conv2d_610[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_587 (LeakyReLU  (None, 52, 52, 256)          0         ['batch_normalization_587[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_194 (  (None, 52, 52, 256)          0         ['tf.__operators__.add_193[0][
#  TFOpLambda)                                                        0]',
#                                                                      'leaky_re_lu_587[0][0]']
#
#  conv2d_611 (Conv2D)         (None, 52, 52, 128)          32768     ['tf.__operators__.add_194[0][
#                                                                     0]']
#
#  batch_normalization_588 (B  (None, 52, 52, 128)          512       ['conv2d_611[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_588 (LeakyReLU  (None, 52, 52, 128)          0         ['batch_normalization_588[0][0
#  )                                                                  ]']
#
#  conv2d_612 (Conv2D)         (None, 52, 52, 256)          294912    ['leaky_re_lu_588[0][0]']
#
#  batch_normalization_589 (B  (None, 52, 52, 256)          1024      ['conv2d_612[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_589 (LeakyReLU  (None, 52, 52, 256)          0         ['batch_normalization_589[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_195 (  (None, 52, 52, 256)          0         ['tf.__operators__.add_194[0][
#  TFOpLambda)                                                        0]',
#                                                                      'leaky_re_lu_589[0][0]']
#
#  conv2d_613 (Conv2D)         (None, 52, 52, 128)          32768     ['tf.__operators__.add_195[0][
#                                                                     0]']
#
#  batch_normalization_590 (B  (None, 52, 52, 128)          512       ['conv2d_613[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_590 (LeakyReLU  (None, 52, 52, 128)          0         ['batch_normalization_590[0][0
#  )                                                                  ]']
#
#  conv2d_614 (Conv2D)         (None, 52, 52, 256)          294912    ['leaky_re_lu_590[0][0]']
#
#  batch_normalization_591 (B  (None, 52, 52, 256)          1024      ['conv2d_614[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_591 (LeakyReLU  (None, 52, 52, 256)          0         ['batch_normalization_591[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_196 (  (None, 52, 52, 256)          0         ['tf.__operators__.add_195[0][
#  TFOpLambda)                                                        0]',
#                                                                      'leaky_re_lu_591[0][0]']
#
#  conv2d_615 (Conv2D)         (None, 52, 52, 128)          32768     ['tf.__operators__.add_196[0][
#                                                                     0]']
#
#  batch_normalization_592 (B  (None, 52, 52, 128)          512       ['conv2d_615[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_592 (LeakyReLU  (None, 52, 52, 128)          0         ['batch_normalization_592[0][0
#  )                                                                  ]']
#
#  conv2d_616 (Conv2D)         (None, 52, 52, 256)          294912    ['leaky_re_lu_592[0][0]']
#
#  batch_normalization_593 (B  (None, 52, 52, 256)          1024      ['conv2d_616[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_593 (LeakyReLU  (None, 52, 52, 256)          0         ['batch_normalization_593[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_197 (  (None, 52, 52, 256)          0         ['tf.__operators__.add_196[0][
#  TFOpLambda)                                                        0]',
#                                                                      'leaky_re_lu_593[0][0]']
#
#  conv2d_617 (Conv2D)         (None, 52, 52, 128)          32768     ['tf.__operators__.add_197[0][
#                                                                     0]']
#
#  batch_normalization_594 (B  (None, 52, 52, 128)          512       ['conv2d_617[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_594 (LeakyReLU  (None, 52, 52, 128)          0         ['batch_normalization_594[0][0
#  )                                                                  ]']
#
#  conv2d_618 (Conv2D)         (None, 52, 52, 256)          294912    ['leaky_re_lu_594[0][0]']
#
#  batch_normalization_595 (B  (None, 52, 52, 256)          1024      ['conv2d_618[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_595 (LeakyReLU  (None, 52, 52, 256)          0         ['batch_normalization_595[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_198 (  (None, 52, 52, 256)          0         ['tf.__operators__.add_197[0][
#  TFOpLambda)                                                        0]',
#                                                                      'leaky_re_lu_595[0][0]']
#
#  zero_padding2d_43 (ZeroPad  (None, 53, 53, 256)          0         ['tf.__operators__.add_198[0][
#  ding2D)                                                            0]']
#
#  conv2d_619 (Conv2D)         (None, 26, 26, 512)          1179648   ['zero_padding2d_43[0][0]']
#
#  batch_normalization_596 (B  (None, 26, 26, 512)          2048      ['conv2d_619[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_596 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_596[0][0
#  )                                                                  ]']
#
#  conv2d_620 (Conv2D)         (None, 26, 26, 256)          131072    ['leaky_re_lu_596[0][0]']
#
#  batch_normalization_597 (B  (None, 26, 26, 256)          1024      ['conv2d_620[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_597 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_597[0][0
#  )                                                                  ]']
#
#  conv2d_621 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_597[0][0]']
#
#  batch_normalization_598 (B  (None, 26, 26, 512)          2048      ['conv2d_621[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_598 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_598[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_199 (  (None, 26, 26, 512)          0         ['leaky_re_lu_596[0][0]',
#  TFOpLambda)                                                         'leaky_re_lu_598[0][0]']
#
#  conv2d_622 (Conv2D)         (None, 26, 26, 256)          131072    ['tf.__operators__.add_199[0][
#                                                                     0]']
#
#  batch_normalization_599 (B  (None, 26, 26, 256)          1024      ['conv2d_622[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_599 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_599[0][0
#  )                                                                  ]']
#
#  conv2d_623 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_599[0][0]']
#
#  batch_normalization_600 (B  (None, 26, 26, 512)          2048      ['conv2d_623[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_600 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_600[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_200 (  (None, 26, 26, 512)          0         ['tf.__operators__.add_199[0][
#  TFOpLambda)                                                        0]',
#                                                                      'leaky_re_lu_600[0][0]']
#
#  conv2d_624 (Conv2D)         (None, 26, 26, 256)          131072    ['tf.__operators__.add_200[0][
#                                                                     0]']
#
#  batch_normalization_601 (B  (None, 26, 26, 256)          1024      ['conv2d_624[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_601 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_601[0][0
#  )                                                                  ]']
#
#  conv2d_625 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_601[0][0]']
#
#  batch_normalization_602 (B  (None, 26, 26, 512)          2048      ['conv2d_625[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_602 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_602[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_201 (  (None, 26, 26, 512)          0         ['tf.__operators__.add_200[0][
#  TFOpLambda)                                                        0]',
#                                                                      'leaky_re_lu_602[0][0]']
#
#  conv2d_626 (Conv2D)         (None, 26, 26, 256)          131072    ['tf.__operators__.add_201[0][
#                                                                     0]']
#
#  batch_normalization_603 (B  (None, 26, 26, 256)          1024      ['conv2d_626[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_603 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_603[0][0
#  )                                                                  ]']
#
#  conv2d_627 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_603[0][0]']
#
#  batch_normalization_604 (B  (None, 26, 26, 512)          2048      ['conv2d_627[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_604 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_604[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_202 (  (None, 26, 26, 512)          0         ['tf.__operators__.add_201[0][
#  TFOpLambda)                                                        0]',
#                                                                      'leaky_re_lu_604[0][0]']
#
#  conv2d_628 (Conv2D)         (None, 26, 26, 256)          131072    ['tf.__operators__.add_202[0][
#                                                                     0]']
#
#  batch_normalization_605 (B  (None, 26, 26, 256)          1024      ['conv2d_628[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_605 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_605[0][0
#  )                                                                  ]']
#
#  conv2d_629 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_605[0][0]']
#
#  batch_normalization_606 (B  (None, 26, 26, 512)          2048      ['conv2d_629[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_606 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_606[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_203 (  (None, 26, 26, 512)          0         ['tf.__operators__.add_202[0][
#  TFOpLambda)                                                        0]',
#                                                                      'leaky_re_lu_606[0][0]']
#
#  conv2d_630 (Conv2D)         (None, 26, 26, 256)          131072    ['tf.__operators__.add_203[0][
#                                                                     0]']
#
#  batch_normalization_607 (B  (None, 26, 26, 256)          1024      ['conv2d_630[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_607 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_607[0][0
#  )                                                                  ]']
#
#  conv2d_631 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_607[0][0]']
#
#  batch_normalization_608 (B  (None, 26, 26, 512)          2048      ['conv2d_631[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_608 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_608[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_204 (  (None, 26, 26, 512)          0         ['tf.__operators__.add_203[0][
#  TFOpLambda)                                                        0]',
#                                                                      'leaky_re_lu_608[0][0]']
#
#  conv2d_632 (Conv2D)         (None, 26, 26, 256)          131072    ['tf.__operators__.add_204[0][
#                                                                     0]']
#
#  batch_normalization_609 (B  (None, 26, 26, 256)          1024      ['conv2d_632[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_609 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_609[0][0
#  )                                                                  ]']
#
#  conv2d_633 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_609[0][0]']
#
#  batch_normalization_610 (B  (None, 26, 26, 512)          2048      ['conv2d_633[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_610 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_610[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_205 (  (None, 26, 26, 512)          0         ['tf.__operators__.add_204[0][
#  TFOpLambda)                                                        0]',
#                                                                      'leaky_re_lu_610[0][0]']
#
#  conv2d_634 (Conv2D)         (None, 26, 26, 256)          131072    ['tf.__operators__.add_205[0][
#                                                                     0]']
#
#  batch_normalization_611 (B  (None, 26, 26, 256)          1024      ['conv2d_634[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_611 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_611[0][0
#  )                                                                  ]']
#
#  conv2d_635 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_611[0][0]']
#
#  batch_normalization_612 (B  (None, 26, 26, 512)          2048      ['conv2d_635[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_612 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_612[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_206 (  (None, 26, 26, 512)          0         ['tf.__operators__.add_205[0][
#  TFOpLambda)                                                        0]',
#                                                                      'leaky_re_lu_612[0][0]']
#
#  zero_padding2d_44 (ZeroPad  (None, 27, 27, 512)          0         ['tf.__operators__.add_206[0][
#  ding2D)                                                            0]']
#
#  conv2d_636 (Conv2D)         (None, 13, 13, 1024)         4718592   ['zero_padding2d_44[0][0]']
#
#  batch_normalization_613 (B  (None, 13, 13, 1024)         4096      ['conv2d_636[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_613 (LeakyReLU  (None, 13, 13, 1024)         0         ['batch_normalization_613[0][0
#  )                                                                  ]']
#
#  conv2d_637 (Conv2D)         (None, 13, 13, 512)          524288    ['leaky_re_lu_613[0][0]']
#
#  batch_normalization_614 (B  (None, 13, 13, 512)          2048      ['conv2d_637[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_614 (LeakyReLU  (None, 13, 13, 512)          0         ['batch_normalization_614[0][0
#  )                                                                  ]']
#
#  conv2d_638 (Conv2D)         (None, 13, 13, 1024)         4718592   ['leaky_re_lu_614[0][0]']
#
#  batch_normalization_615 (B  (None, 13, 13, 1024)         4096      ['conv2d_638[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_615 (LeakyReLU  (None, 13, 13, 1024)         0         ['batch_normalization_615[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_207 (  (None, 13, 13, 1024)         0         ['leaky_re_lu_613[0][0]',
#  TFOpLambda)                                                         'leaky_re_lu_615[0][0]']
#
#  conv2d_639 (Conv2D)         (None, 13, 13, 512)          524288    ['tf.__operators__.add_207[0][
#                                                                     0]']
#
#  batch_normalization_616 (B  (None, 13, 13, 512)          2048      ['conv2d_639[0][0]']
#  atchNormalization)
#
# ...
#                                                                      'tf.__operators__.getitem_89[
#                                                                     0][0]',
#                                                                      'tf.__operators__.getitem_89[
#                                                                     0][0]']
#
#  tf.__operators__.getitem_9  (1, 13, 13, 1, 2)            0         ['tf.concat_36[0][0]']
#  6 (SlicingOpLambda)
#
#  tf.__operators__.getitem_7  (None, 52, 52, 3, 2)         0         ['tf.reshape_9[0][0]']
#  2 (SlicingOpLambda)
#
#  tf.tile_20 (TFOpLambda)     (None, 52, 52, 3, 2)         0         ['tf.__operators__.getitem_78[
#                                                                     0][0]',
#                                                                      'tf.__operators__.getitem_70[
#                                                                     0][0]']
#
#  tf.__operators__.getitem_7  (None, 52, 52, 3, 2)         0         ['tf.reshape_9[0][0]']
#  3 (SlicingOpLambda)
#
#  tf.__operators__.getitem_8  (None, 26, 26, 3, 2)         0         ['tf.reshape_10[0][0]']
#  1 (SlicingOpLambda)
#
#  tf.tile_23 (TFOpLambda)     (None, 26, 26, 3, 2)         0         ['tf.__operators__.getitem_87[
#                                                                     0][0]',
#                                                                      'tf.__operators__.getitem_79[
#                                                                     0][0]']
#
#  tf.__operators__.getitem_8  (None, 26, 26, 3, 2)         0         ['tf.reshape_10[0][0]']
#  2 (SlicingOpLambda)
#
#  tf.__operators__.getitem_9  (None, 13, 13, 3, 2)         0         ['tf.reshape_11[0][0]']
#  0 (SlicingOpLambda)
#
#  tf.tile_26 (TFOpLambda)     (None, 13, 13, 3, 2)         0         ['tf.__operators__.getitem_96[
#                                                                     0][0]',
#                                                                      'tf.__operators__.getitem_88[
#                                                                     0][0]']
#
#  tf.__operators__.getitem_9  (None, 13, 13, 3, 2)         0         ['tf.reshape_11[0][0]']
#  1 (SlicingOpLambda)
#
#  tf.math.sigmoid_12 (TFOpLa  (None, 52, 52, 3, 2)         0         ['tf.__operators__.getitem_72[
#  mbda)                                                              0][0]']
#
#  tf.cast_4 (TFOpLambda)      (None, 52, 52, 3, 2)         0         ['tf.tile_20[0][0]']
#
#  tf.math.exp_4 (TFOpLambda)  (None, 52, 52, 3, 2)         0         ['tf.__operators__.getitem_73[
#                                                                     0][0]']
#
#  tf.math.sigmoid_15 (TFOpLa  (None, 26, 26, 3, 2)         0         ['tf.__operators__.getitem_81[
#  mbda)                                                              0][0]']
#
#  tf.cast_5 (TFOpLambda)      (None, 26, 26, 3, 2)         0         ['tf.tile_23[0][0]']
#
#  tf.math.exp_5 (TFOpLambda)  (None, 26, 26, 3, 2)         0         ['tf.__operators__.getitem_82[
#                                                                     0][0]']
#
#  tf.math.sigmoid_18 (TFOpLa  (None, 13, 13, 3, 2)         0         ['tf.__operators__.getitem_90[
#  mbda)                                                              0][0]']
#
#  tf.cast_6 (TFOpLambda)      (None, 13, 13, 3, 2)         0         ['tf.tile_26[0][0]']
#
#  tf.math.exp_6 (TFOpLambda)  (None, 13, 13, 3, 2)         0         ['tf.__operators__.getitem_91[
#                                                                     0][0]']
#
#  tf.__operators__.add_211 (  (None, 52, 52, 3, 2)         0         ['tf.math.sigmoid_12[0][0]',
#  TFOpLambda)                                                         'tf.cast_4[0][0]']
#
#  tf.math.multiply_13 (TFOpL  (None, 52, 52, 3, 2)         0         ['tf.math.exp_4[0][0]']
#  ambda)
#
#  tf.__operators__.add_212 (  (None, 26, 26, 3, 2)         0         ['tf.math.sigmoid_15[0][0]',
#  TFOpLambda)                                                         'tf.cast_5[0][0]']
#
#  tf.math.multiply_16 (TFOpL  (None, 26, 26, 3, 2)         0         ['tf.math.exp_5[0][0]']
#  ambda)
#
#  tf.__operators__.add_213 (  (None, 13, 13, 3, 2)         0         ['tf.math.sigmoid_18[0][0]',
#  TFOpLambda)                                                         'tf.cast_6[0][0]']
#
#  tf.math.multiply_19 (TFOpL  (None, 13, 13, 3, 2)         0         ['tf.math.exp_6[0][0]']
#  ambda)
#
#  tf.math.multiply_12 (TFOpL  (None, 52, 52, 3, 2)         0         ['tf.__operators__.add_211[0][
#  ambda)                                                             0]']
#
#  tf.math.multiply_14 (TFOpL  (None, 52, 52, 3, 2)         0         ['tf.math.multiply_13[0][0]']
#  ambda)
#
#  tf.__operators__.getitem_7  (None, 52, 52, 3, 1)         0         ['tf.reshape_9[0][0]']
#  4 (SlicingOpLambda)
#
#  tf.__operators__.getitem_7  (None, 52, 52, 3, 10)        0         ['tf.reshape_9[0][0]']
#  5 (SlicingOpLambda)
#
#  tf.math.multiply_15 (TFOpL  (None, 26, 26, 3, 2)         0         ['tf.__operators__.add_212[0][
#  ambda)                                                             0]']
#
#  tf.math.multiply_17 (TFOpL  (None, 26, 26, 3, 2)         0         ['tf.math.multiply_16[0][0]']
#  ambda)
#
#  tf.__operators__.getitem_8  (None, 26, 26, 3, 1)         0         ['tf.reshape_10[0][0]']
#  3 (SlicingOpLambda)
#
#  tf.__operators__.getitem_8  (None, 26, 26, 3, 10)        0         ['tf.reshape_10[0][0]']
#  4 (SlicingOpLambda)
#
#  tf.math.multiply_18 (TFOpL  (None, 13, 13, 3, 2)         0         ['tf.__operators__.add_213[0][
#  ambda)                                                             0]']
#
#  tf.math.multiply_20 (TFOpL  (None, 13, 13, 3, 2)         0         ['tf.math.multiply_19[0][0]']
#  ambda)
#
#  tf.__operators__.getitem_9  (None, 13, 13, 3, 1)         0         ['tf.reshape_11[0][0]']
#  2 (SlicingOpLambda)
#
#  tf.__operators__.getitem_9  (None, 13, 13, 3, 10)        0         ['tf.reshape_11[0][0]']
#  3 (SlicingOpLambda)
#
#  tf.concat_31 (TFOpLambda)   (None, 52, 52, 3, 4)         0         ['tf.math.multiply_12[0][0]',
#                                                                      'tf.math.multiply_14[0][0]']
#
#  tf.math.sigmoid_13 (TFOpLa  (None, 52, 52, 3, 1)         0         ['tf.__operators__.getitem_74[
#  mbda)                                                              0][0]']
#
#  tf.math.sigmoid_14 (TFOpLa  (None, 52, 52, 3, 10)        0         ['tf.__operators__.getitem_75[
#  mbda)                                                              0][0]']
#
#  tf.concat_34 (TFOpLambda)   (None, 26, 26, 3, 4)         0         ['tf.math.multiply_15[0][0]',
#                                                                      'tf.math.multiply_17[0][0]']
#
#  tf.math.sigmoid_16 (TFOpLa  (None, 26, 26, 3, 1)         0         ['tf.__operators__.getitem_83[
#  mbda)                                                              0][0]']
#
#  tf.math.sigmoid_17 (TFOpLa  (None, 26, 26, 3, 10)        0         ['tf.__operators__.getitem_84[
#  mbda)                                                              0][0]']
#
#  tf.concat_37 (TFOpLambda)   (None, 13, 13, 3, 4)         0         ['tf.math.multiply_18[0][0]',
#                                                                      'tf.math.multiply_20[0][0]']
#
#  tf.math.sigmoid_19 (TFOpLa  (None, 13, 13, 3, 1)         0         ['tf.__operators__.getitem_92[
#  mbda)                                                              0][0]']
#
#  tf.math.sigmoid_20 (TFOpLa  (None, 13, 13, 3, 10)        0         ['tf.__operators__.getitem_93[
#  mbda)                                                              0][0]']
#
#  tf.concat_32 (TFOpLambda)   (None, 52, 52, 3, 15)        0         ['tf.concat_31[0][0]',
#                                                                      'tf.math.sigmoid_13[0][0]',
#                                                                      'tf.math.sigmoid_14[0][0]']
#
#  tf.concat_35 (TFOpLambda)   (None, 26, 26, 3, 15)        0         ['tf.concat_34[0][0]',
#                                                                      'tf.math.sigmoid_16[0][0]',
#                                                                      'tf.math.sigmoid_17[0][0]']
#
#  tf.concat_38 (TFOpLambda)   (None, 13, 13, 3, 15)        0         ['tf.concat_37[0][0]',
#                                                                      'tf.math.sigmoid_19[0][0]',
#                                                                      'tf.math.sigmoid_20[0][0]']
#
# ==================================================================================================
# Total params: 61624807 (235.08 MB)
# Trainable params: 61572199 (234.88 MB)
# Non-trainable params: 52608 (205.50 KB)
# __________________________________________________________________________________________________
